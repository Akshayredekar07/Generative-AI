# %%
# ! uv pip install weaviate-client langchain tiktoken pypdf rapidocr-onnxruntime
# ! uv pip install --upgrade protobuf
# ! uv pip install --upgrade google-api-core google-cloud-core googleapis-common-protos
# ! uv pip install --upgrade google-generativeai langchain-google-genai
# ! uv pip install sentence-transformers
# ! uv pip install weaviate-client==3.26.7
# ! uv pip install langchain pgvector psycopg[binary] sqlalchemy

# ! uv pip uninstall weaviate-client
# ! uv pip install weaviate-client==3.26.2
# ! uv pip install --upgrade langchain

# ! uv pip install psycopg2-binary

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.vectorstores.pgvector import PGVector

# %%
from langchain.embeddings import OllamaEmbeddings
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %% [markdown]
# #### **Loading Different Types of PDFs with LangChain**
#
# You can load multiple types of PDF documents using LangChain. Just refer to the official documentation for supported formats and loaders:
#
# 🔗 [LangChain PDF Document Loaders](https://python.langchain.com/docs/modules/data_connection/document_loaders/pdf/)

# %%
from langchain.document_loaders import PyMuPDFLoader
loader=PyMuPDFLoader(r"C:\Users\Admin\Documents\Aptitude\percetnages_merged.pdf", extract_images=True)
pages=loader.load()
# Out:
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type swigvarlink has no __module__ attribute

# %%
pages
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 0}, page_content='1\nIntroduction\n2\nPercentage Splitting Technique\nThe percentage splitting method involves breaking down a percentage into smaller, man-\nageable parts, calculating each part, and summing the results.\n2.1\nSteps\n1. Identify the whole value and the percentage to calculate.\n2. Break the percentage into simpler parts (e.g., 50%, 25%, 10%, 5%, 1%).\n3. Calculate each part based on the whole value.\n4. Sum the parts to ﬁnd the ﬁnal result.\n2.2\nCommon Splits\n• 100% = Whole value.\n• 50% = Whole ÷ 2.\n• 25% = 50% ÷ 2.\n• 10% = Whole ÷ 10.\n• 5% = 10% ÷ 2.\n• 1% = Whole ÷ 100.\n3\nTips for Percentage Splitting\n• Start with larger percentages (e.g., 50%, 25%) to minimize steps.\n• Use 10% and 1% for ﬁne adjustments.\n• Practice mental division to compute 50%, 10%, etc., quickly.\n• Double-check by approximating: e.g., 77.5% is close to 75%, so the answer should\nbe slightly more than 75%.\n4\nExamples\n4.1\nExample 1: 77.5% of 200 (Basic Splitting)\nBreak down 77.5%:\n• 100% = 200.\n• 50% = 200 ÷ 2 = 100.\n• 25% = 100 ÷ 2 = 50.\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 1}, page_content='• 2.5% = 25% ÷ 10 = 50 ÷ 10 = 5.\nCompose 77.5% = 50% + 25% + 2.5%:\n100 + 50 + 5 = 155\nSo, 77.5% of 200 = 155.\n4.2\nExample 2: 65% of 128 (Adjusting with Smaller Percent-\nages)\nBreak down 65%:\n• 100% = 128.\n• 50% = 128 ÷ 2 = 64.\n• 10% = 128 ÷ 10 = 12.8.\n• 5% = 10% ÷ 2 = 12.8 ÷ 2 = 6.4.\nCompose 65% = 50% + 10% + 5%:\n64 + 12.8 + 6.4 = 83.2\nSo, 65% of 128 = 83.2.\n4.3\nExample 3: 37.5% of 80 (Budget Allocation)\nA student has a monthly budget of $80 and spends 37.5% on books. How much do they\nspend? Break down 37.5%:\n• 100% = 80.\n• 25% = 80 ÷ 4 = 20.\n• 10% = 80 ÷ 10 = 8.\n• 2.5% = 25% ÷ 10 = 20 ÷ 10 = 2.\nCompose 37.5% = 25% + 10% + 2.5%:\n20 + 8 + 2 = 30\nSo, the student spends $30 on books.\n5\nReal-Life TCS NQT Examples\nThe following examples reﬂect real-life scenarios often tested in the TCS NQT exam’s\nnumerical ability section, solved using percentage splitting.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 2}, page_content='5.1\nExample 4: Proﬁt Calculation\nA shopkeeper buys an item for $200 and sells it at a 17.5% proﬁt. What is the selling\nprice? First, calculate the proﬁt amount (17.5% of 200):\n• 100% = 200.\n• 10% = 200 ÷ 10 = 20.\n• 5% = 10% ÷ 2 = 20 ÷ 2 = 10.\n• 2.5% = 5% ÷ 2 = 10 ÷ 2 = 5.\nCompose 17.5% = 10% + 5% + 2.5%:\n20 + 10 + 5 = 35\nProﬁt = $35. Selling Price = Cost Price + Proﬁt = 200 + 35 = $235.\n5.2\nExample 5: Election Voting\nIn an election, a candidate receives 62.5% of 800 valid votes. How many votes did the\ncandidate get? Break down 62.5%:\n• 100% = 800.\n• 50% = 800 ÷ 2 = 400.\n• 12.5% = 50% ÷ 4 = 400 ÷ 4 = 100.\nCompose 62.5% = 50% + 12.5%:\n400 + 100 = 500\nThe candidate received 500 votes.\n5.3\nExample 6: Discount on a Product\nA laptop priced at $1200 has a 22.5% discount during a sale.\nWhat is the discount\namount? Break down 22.5%:\n• 100% = 1200.\n• 20% = 1200 ÷ 5 = 240.\n• 2.5% = 25% ÷ 10 = (1200 ÷ 4) ÷ 10 = 300 ÷ 10 = 30.\nCompose 22.5% = 20% + 2.5%:\n240 + 30 = 270\nThe discount amount is $270.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 3}, page_content='5.4\nExample 7: Employee Salary Increment\nAn employees salary of $50,000 increases by 12.5% after a promotion. What is the new\nsalary? First, calculate the increment (12.5% of 50,000):\n• 100% = 50,000.\n• 10% = 50,000 ÷ 10 = 5,000.\n• 2.5% = 25% ÷ 10 = (50,000 ÷ 4) ÷ 10 = 12,500 ÷ 10 = 1,250.\nCompose 12.5% = 10% + 2.5%:\n5, 000 + 1, 250 = 6, 250\nIncrement = $6,250. New Salary = 50,000 + 6,250 = $56,250.\n6\nPractice Questions\n1. Find 62.5% of 160 using percentage splitting.\n2. Calculate 87.5% of 40 by breaking it into simpler parts.\n3. What is 42.5% of 200 using the splitting method?\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 4}, page_content='Detailed Solution for Percentage Change Problems\nJune 12, 2025\nIntroduction\nThis document provides a detailed solution to two problems involving percentage changes.\nThe first problem calculates the reduction in consumption of a commodity when its price\nincreases, keeping expenditure constant. The second problem determines the percent-\nage by which one quantity is less or more than another after a percentage change. All\ncalculations are verified with the given formulas.\n1\nReduction in Consumption Due to Price Increase\n1.1\nProblem Statement\nIf the price of a commodity increases by R%, we need to find the reduction in consumption\nto keep the expenditure constant. The given data is as follows:\n• Initial price: Rs 10/kg\n• Initial consumption: 20 kg\n• Total expenditure: Rs 200/month\n• New price after increase: Rs 20/kg\n• Expenditure remains constant at Rs 200/month\nThe formula provided is:\n• If price increases by R%, reduction in consumption =\n100\n100 + R × 100%\n• If price decreases by R%, reduction in consumption =\n100\n100 −R × 100%\n1.2\nSolution\n1. Calculate Initial Expenditure:\nInitial price = 10 Rs/kg,\nInitial consumption = 20 kg\nTotal expenditure = Price × Consumption = 10 × 20 = 200 Rs/month\n2. Determine New Consumption After Price Increase:\nNew price = 20 Rs/kg,\nExpenditure = 200 Rs/month\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 5}, page_content='Let the new consumption be Y kg. Since expenditure remains constant:\nNew price × New consumption = Expenditure\n20 × Y = 200\nY = 200\n20 = 10 kg\nSo, consumption reduces from 20 kg to 10 kg.\n3. Calculate Percentage Increase in Price (R%):\nInitial price = 10 Rs/kg,\nNew price = 20 Rs/kg\nIncrease in price = 20 −10 = 10 Rs/kg\nR = Increase in price\nInitial price\n× 100 = 10\n10 × 100 = 100%\n4. Calculate Reduction in Consumption:\nInitial consumption = 20 kg,\nNew consumption = 10 kg\nReduction in consumption = 20 −10 = 10 kg\nPercentage reduction = Reduction in consumption\nInitial consumption\n× 100 = 10\n20 × 100 = 50%\n5. Verify Using the Given Formula: For price increase by R%:\nReduction in consumption =\n100\n100 + R × 100%\nHere, R = 100:\nReduction =\n100\n100 + 100 × 100 = 100\n200 × 100 = 50%\nThis matches our calculation.\n6. Explanation of the Formula: Expenditure = Price × Consumption. If price in-\ncreases by R%, new price = Initial price ×100 + R\n100\n. To keep expenditure constant:\nNew consumption = Initial consumption ×\n100\n100 + R\nPercentage reduction =\n(\n1 −\n100\n100 + R\n)\n× 100 =\nR\n100 + R × 100%\n1.3\nConclusion\nThe price increased by 100%, and consumption reduced by 50% to keep expenditure\nconstant at Rs 200/month. The formula\n100\n100 + R × 100% is verified.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 6}, page_content='2\nPercentage Comparison Between Two Quantities\n2.1\nProblem Statement\nIf A is R% more than B, then B is less than A by some percentage. If A is R% less than\nB, then B is more than A by some percentage. The given data is:\n• A = 120, B = 100\nThe formulas provided are:\n• B is less than A by\nR\n100 + R × 100%\n• B is more than A by\nR\n100 −R × 100%\n2.2\nSolution\n1. Case 1: A is R% More Than B:\nB = 100,\nA = 120\nA = B × 100 + R\n100\n120 = 100 × 100 + R\n100\n100 + R\n100\n= 120\n100\n100 + R = 120\nR = 20\nSo, A is 20% more than B.\n2. Calculate How Much Less B is Than A:\nA = 120,\nB = 100\nDifference = A −B = 120 −100 = 20\nPercentage by which B is less than A = A −B\nA\n×100 = 20\n120×100 = 100\n6\n≈16.67%\n3. Verify Using the Given Formula:\nPercentage =\nR\n100 + R × 100%\nR = 20\n20\n100 + 20 × 100 = 20\n120 × 100 = 100\n6\n≈16.67%\nThis matches our calculation.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 7}, page_content='4. Explanation of the Formula:\nA = B × 100 + R\n100\nB = A ×\n100\n100 + R\nPercentage by which B is less than A =\n(\n1 −\n100\n100 + R\n)\n× 100 =\nR\n100 + R × 100%\n5. Case 2: If A is R% Less Than B: The formula for when A is R% less than B,\nand we need to find how much more B is than A, is:\nR\n100 −R × 100%\n2.3\nConclusion\nWhen A = 120 and B = 100, A is 20% more than B, and B is 16.67% less than A. The\nformula\nR\n100 + R × 100% is verified.\n3\nGeneral Formulas\n• Price increases by R%: Reduction in consumption =\n100\n100 + R × 100%\n• Price decreases by R%: Reduction in consumption =\n100\n100 −R × 100%\n• A is R% more than B: B is less than A by\nR\n100 + R × 100%\n• A is R% less than B: B is more than A by\nR\n100 −R × 100%\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 8}, page_content='Compound Growth: Population Increase Over Time\nConcept Overview\nThis section deals with calculating the population of a town that grows at a constant rate\nof R% per year over n years, starting from an initial population P. This is an example\nof compound growth, where the increase each year is applied to the new population.\nFormula\nPopulation after n years = P\n(\n1 + R\n100\n)n\nExplanation of Formula\nThe formula represents compound growth:\n• P is the initial population.\n• R is the annual growth rate in percentage.\n• n is the number of years.\n• Each year, the population increases by R% of the previous year’s population. After\n1 year, the population is P\n(\n1 +\nR\n100\n)\n. After 2 years, it’s P\n(\n1 +\nR\n100\n)2, and after n\nyears, it’s P\n(\n1 +\nR\n100\n)n.\nApplications and Tips\n• Applications: Used in demographics, urban planning, and financial growth sce-\nnarios (like compound interest).\n• Tip 1 – Multiplier Method: Convert R% to a multiplier: 1+ R\n100. For R = 10%,\nthe multiplier is 1.1.\n• Tip 2 – Memorize Common Powers: For R = 10%, (1.1)2 = 1.21, (1.1)3 =\n1.331. This helps in quick calculations.\n• Tip 3 – Verify First Year: After 1 year, the population should be P × (1 + R\n100),\nwhich is a good check.\nExamples with Detailed Steps\nExample 1: Population Growth Calculation\nProblem: A town has a population of 10,000, and it increases at 5% per year. What will\nthe population be after 3 years?\nSolution:\nStep 1: Identify the given values.\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 9}, page_content='- Initial population, P = 10, 000.\n- Growth rate, R = 5%.\n- Number of years, n = 3.\nStep 2: Apply the formula.\n- Formula: Population = P\n(\n1 +\nR\n100\n)n.\n- Substitute the values: Population = 10, 000\n(\n1 +\n5\n100\n)3.\nStep 3: Calculate the multiplier.\n- 1 +\n5\n100 = 1 + 0.05 = 1.05.\nStep 4: Compute the power (1.05)3.\n- First, (1.05)2 = 1.05 × 1.05 = 1.1025.\n- Then, (1.05)3 = 1.1025 × 1.05 = 1.157625.\nStep 5: Calculate the final population.\n- Population = 10, 000 × 1.157625 = 11, 576.25.\nAnswer: The population after 3 years is approximately 11,576.\nExample 2: Time to Double Population\nProblem: A town’s population is 20,000, growing at 10% per year. In how many years\nwill it double?\nSolution:\nStep 1: Identify the given values.\n- Initial population, P = 20, 000.\n- Target population = 2 × 20, 000 = 40, 000.\n- Growth rate, R = 10%.\nStep 2: Set up the equation using the formula.\n- Formula: 40, 000 = 20, 000\n(\n1 + 10\n100\n)n.\n- Simplify:\n40,000\n20,000 = (1.1)n =⇒2 = (1.1)n.\nStep 3: Estimate n by calculating powers of 1.1.\n- (1.1)7 ≈1.9487 (since 1.1 × 1.1 = 1.21, 1.21 × 1.1 = 1.331, etc.).\n- (1.1)8 ≈2.1436.\nStep 4: Determine the range.\n- Since (1.1)7 < 2 and (1.1)8 > 2, n is between 7 and 8 years.\n- For precision, use logarithms: n =\nlog(2)\nlog(1.1) ≈7.27.\nAnswer: The population doubles in approximately 7.27 years.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 10}, page_content='Compound Depreciation: Value Decrease Over Time\nConcept Overview\nThis section calculates the value of an object that depreciates at a rate of R% per year\nover n years, starting from an initial value P. Depreciation is the opposite of growth,\nwhere the value decreases annually.\nFormula\nValue after n years = P\n(\n1 −R\n100\n)n\nExplanation of Formula\nThe formula represents compound depreciation:\n• P is the initial value.\n• R is the annual depreciation rate in percentage.\n• n is the number of years.\n• Each year, the value decreases by R% of the previous year’s value. After 1 year,\nthe value is P\n(\n1 −\nR\n100\n)\n. After n years, it’s P\n(\n1 −\nR\n100\n)n.\nApplications and Tips\n• Applications: Used for assets like cars, machinery, or electronics that lose value\nover time.\n• Tip 1 – Multiplier Method: For R = 10%, the depreciation multiplier is 1−10\n100 =\n0.9.\n• Tip 2 – Memorize Powers: For R = 10%, (0.9)2 = 0.81, (0.9)3 = 0.729.\n• Tip 3 – First Year Check: After 1 year, the value should be P × (1 −\nR\n100).\nExamples with Detailed Steps\nExample 1: Car Depreciation\nProblem: A car is worth Rs 500,000 and depreciates at 15% per year. What is its value\nafter 2 years?\nSolution:\nStep 1: Identify the given values.\n- Initial value, P = 500, 000.\n- Depreciation rate, R = 15%.\n- Number of years, n = 2.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 11}, page_content='Step 2: Apply the formula.\n- Formula: Value = P\n(\n1 −\nR\n100\n)n.\n- Substitute the values: Value = 500, 000\n(\n1 −15\n100\n)2.\nStep 3: Calculate the multiplier.\n- 1 −15\n100 = 1 −0.15 = 0.85.\nStep 4: Compute the power (0.85)2.\n- (0.85)2 = 0.85 × 0.85 = 0.7225.\nStep 5: Calculate the final value.\n- Value = 500, 000 × 0.7225 = 361, 250.\nAnswer: The car’s value after 2 years is Rs 361,250.\nExample 2: Machine Value Threshold\nProblem: A machine worth Rs 100,000 depreciates at 20% per year. After how many\nyears will its value be less than Rs 40,000?\nSolution:\nStep 1: Identify the given values.\n- Initial value, P = 100, 000.\n- Target value < 40,000.\n- Depreciation rate, R = 20%.\nStep 2: Set up the equation.\n- Formula: 40, 000 = 100, 000\n(\n1 −20\n100\n)n.\n- Simplify:\n40,000\n100,000 = (0.8)n =⇒0.4 = (0.8)n.\nStep 3: Estimate n by calculating powers of 0.8.\n- (0.8)2 = 0.64.\n- (0.8)3 = 0.512.\n- (0.8)4 = 0.4096.\n- (0.8)5 = 0.32768.\nStep 4: Determine when the value is less than 0.4.\n- At n = 4, (0.8)4 = 0.4096, which is just above 0.4.\n- At n = 5, (0.8)5 = 0.32768, which is below 0.4.\n- Therefore, the value drops below 40,000 after 5 years.\nAnswer: The machine’s value is less than Rs 40,000 after 5 years.\nPercentage Allocation: Salary and Expenditure\nConcept Overview\nThis section involves calculating a person’s salary based on their expenditure percentages\nand remaining savings. The total salary is the sum of expenditure and savings, where\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 12}, page_content='percentages of the salary are allocated to various expenses.\nProblem Statement\nDeepak spends 25% of his salary on house rent, 20% on his children’s education, and 10%\non clothes. After these expenses, he is left with Rs 15,600. What is Deepak’s salary?\nOptions: A. 30,000, B. 32,000, C. 31,200, D. 32,500.\nSolution Approach\n• Salary = Expenditure + Savings.\n• Calculate total expenditure percentage.\n• Savings percentage = 100% - Expenditure percentage.\n• Use the savings amount to find the salary.\nDetailed Steps\nStep 1: Calculate total expenditure percentage.\n- House rent = 25%.\n- Education = 20%.\n- Clothes = 10%.\n- Total expenditure = 25 + 20 + 10 = 55%.\nStep 2: Calculate savings percentage.\n- Savings percentage = 100 −55 = 45%.\nStep 3: Set up the equation for savings.\n- 45% of Salary = Rs 15,600.\n- Let Salary = S. Then, 0.45S = 15, 600.\nStep 4: Solve for the salary.\n- S = 15,600\n0.45 .\n- Simplify: S = 15, 600 × 100\n45 = 15, 600 × 20\n9 ≈34, 666.67.\nStep 5: Compare with options.\n- Calculated salary ≈34, 667, which does not match any options (30,000, 32,000, 31,200,\n32,500).\n- This suggests a potential error in the problem’s options.\nThe closest option is not\ncorrect, but for the sake of the problem, let’s note the discrepancy.\nAnswer: The calculated salary is approximately Rs 34,667, but none of the options match.\nThere may be an error in the problem’s options.\nExamples with Detailed Steps\nExample 1: Adjusted Savings Percentage\nProblem: A person spends 30% on rent, 15% on food, and 10% on travel. After expenses,\n5'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 13}, page_content='they save Rs 22,500. What is their salary?\nSolution:\nStep 1: Calculate total expenditure percentage.\n- Rent = 30%.\n- Food = 15%.\n- Travel = 10%.\n- Total expenditure = 30 + 15 + 10 = 55%.\nStep 2: Calculate savings percentage.\n- Savings = 100 −55 = 45%.\nStep 3: Set up the equation.\n- 45% of Salary = 22,500.\n- Salary = 22,500\n0.45 .\nStep 4: Solve for the salary.\n- Salary = 22, 500 × 100\n45 = 22, 500 × 20\n9 = 50, 000.\nAnswer: The salary is Rs 50,000.\nExample 2: Different Percentages\nProblem: A person spends 20% on rent, 10% on food, and 5% on entertainment. They\nsave Rs 52,500. What is their salary?\nSolution:\nStep 1: Calculate total expenditure percentage.\n- Rent = 20%.\n- Food = 10%.\n- Entertainment = 5%.\n- Total expenditure = 20 + 10 + 5 = 35%.\nStep 2: Calculate savings percentage.\n- Savings = 100 −35 = 65%.\nStep 3: Set up the equation.\n- 65% of Salary = 52,500.\n- Salary = 52,500\n0.65 .\nStep 4: Solve for the salary.\n- Salary = 52, 500 × 100\n65 = 52, 500 × 20\n13 ≈80, 769.23.\nAnswer: The salary is approximately Rs 80,769.\n6'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='Percentage Change in Area Due to Dimension In-\ncrease\nConcept Overview\nThis section calculates the percentage change in the area of a rectangle when its dimen-\nsions (length and breadth) are increased by given percentages. Since the cost of land is\nproportional to its area, the percentage change in area equals the percentage change in\ncost.\nProblem Statement\nA person increases the length of a rectangular land by 15% and the breadth by 20%.\nFind the percentage change in the cost of the land, assuming land prices are uniform.\nOptions: A. 42%, B. 38%, C. 30%, D. 45%.\nSolution Approach\n• Area of a rectangle = Length × Breadth.\n• New length = Original length ×(1 + Length increase %\n100\n).\n• New breadth = Original breadth ×(1 + Breadth increase %\n100\n).\n• Percentage change = New Area−Original Area\nOriginal Area\n× 100.\nDetailed Steps\nStep 1: Assume initial dimensions.\n- Let original length = 100 units.\n- Let original breadth = 100 units.\n- Original area = 100 × 100 = 10, 000 square units.\nStep 2: Calculate new dimensions.\n- New length = 100 × (1 + 15\n100) = 100 × 1.15 = 115 units.\n- New breadth = 100 × (1 + 20\n100) = 100 × 1.20 = 120 units.\nStep 3: Calculate new area.\n- New area = 115 × 120 = 13, 800 square units.\nStep 4: Find the increase in area.\n- Increase = 13, 800 −10, 000 = 3, 800 square units.\nStep 5: Calculate percentage increase.\n- Percentage increase =\n3,800\n10,000 × 100 = 38%.\nAnswer: The percentage change in cost is 38% (Option B).\n7'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 15}, page_content='Examples with Detailed Steps\nExample 1: Different Increases\nProblem: A rectangle’s length increases by 10% and breadth by 5%. Find the percentage\nincrease in area.\nSolution:\nStep 1: Assume initial dimensions.\n- Length = 100 units.\n- Breadth = 100 units.\n- Original area = 100 × 100 = 10, 000.\nStep 2: Calculate new dimensions.\n- New length = 100 × 1.10 = 110 units.\n- New breadth = 100 × 1.05 = 105 units.\nStep 3: Calculate new area.\n- New area = 110 × 105 = 11, 550.\nStep 4: Find the increase.\n- Increase = 11, 550 −10, 000 = 1, 550.\nStep 5: Calculate percentage increase.\n- Percentage increase =\n1,550\n10,000 × 100 = 15.5%.\nAnswer: The area increases by 15.5%.\nExample 2: Decrease in Dimensions\nProblem: A rectangle’s length decreases by 10% and breadth by 20%. Find the percentage\ndecrease in area.\nSolution:\nStep 1: Assume initial dimensions.\n- Length = 100 units.\n- Breadth = 100 units.\n- Original area = 100 × 100 = 10, 000.\nStep 2: Calculate new dimensions.\n- New length = 100 × (1 −0.10) = 90 units.\n- New breadth = 100 × (1 −0.20) = 80 units.\nStep 3: Calculate new area.\n- New area = 90 × 80 = 7, 200.\nStep 4: Find the decrease.\n- Decrease = 10, 000 −7, 200 = 2, 800.\nStep 5: Calculate percentage decrease.\n- Percentage decrease =\n2,800\n10,000 × 100 = 28%.\n8'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='Answer: The area decreases by 28%.\nElection Voting with Percentage Difference\nConcept Overview\nThis section deals with calculating the difference in votes between two parties in an\nelection, where one party secures a percentage more votes than the other, and the total\nvotes are split between them.\nProblem Statement\nIn an election contested by two parties, Party A secured 12% more of the total votes than\nParty B. Party B got 13,200 votes, and there are no invalid votes. By how many votes\ndid Party B lose the election?\nOptions: A. 1,600, B. 2,500, C. 2,400, D. 3,600.\nSolution Approach\n• Party A’s votes are 12% more than Party B’s.\n• Total votes = Party A votes + Party B votes.\n• Find total votes, then calculate the difference.\nDetailed Steps\nStep 1: Define votes in terms of percentages.\n- Let Party B’s votes = 100 units (for percentage calculation).\n- Party A’s votes = 100 × (1 + 0.12) = 112 units.\n- Total votes = 100 + 112 = 212 units.\nStep 2: Calculate percentage split.\n- Party B’s percentage = 100\n212 × 100 ≈47.17%.\n- Party A’s percentage = 112\n212 × 100 ≈52.83%.\n- Difference = 52.83 −47.17 = 12% of total votes (as given).\nStep 3: Use Party B’s votes to find total votes.\n- Party B = 13,200 votes, which is 47.17% of total.\n- Total votes = 13,200\n0.4717 ≈27, 984.\n- Alternatively, use the diagram’s approach: If Party B = 44% (since A is 12% more, A\n= 56%, total = 100% - 12% = 88%, B = 44%), then:\n- Total votes = 13,200\n0.44 = 30, 000.\nStep 4: Calculate Party A’s votes.\n- Party A = 56% of 30,000 = 0.56 × 30, 000 = 16, 800.\nStep 5: Find the difference.\n- Difference = 16, 800 −13, 200 = 3, 600.\n9'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 17}, page_content='Answer: Party B lost by 3,600 votes (Option D).\nExamples with Detailed Steps\nExample 1: Different Percentage Difference\nProblem: Party A gets 20% more votes than Party B. Party B has 10,000 votes. Find\nthe difference.\nSolution:\nStep 1: Define votes.\n- Party B = 100 units.\n- Party A = 100 × 1.20 = 120 units.\n- Total = 100 + 120 = 220 units.\nStep 2: Calculate percentage split.\n- Party B = 100\n220 × 100 ≈45.45%.\nStep 3: Find total votes.\n- 45.45% = 10,000.\n- Total votes = 10,000\n0.4545 ≈22, 000.\nStep 4: Calculate difference.\n- Difference = 20% of 22,000 = 0.20 × 22, 000 = 4, 400.\nAnswer: The difference is 4,400 votes.\nExample 2: With Invalid Votes\nProblem: Party A gets 10% more votes than Party B. Party B has 12,000 votes, and 5%\nof total votes are invalid. Find the difference in valid votes.\nSolution:\nStep 1: Define votes.\n- Party B = 100 units.\n- Party A = 100 × 1.10 = 110 units.\n- Total valid votes = 100 + 110 = 210 units.\nStep 2: Calculate percentage of valid votes.\n- Party B = 100\n210 × 100 ≈47.62%.\nStep 3: Find total valid votes.\n- 47.62% = 12,000.\n- Total valid votes = 12,000\n0.4762 ≈25, 200.\nStep 4: Include invalid votes.\n- Valid votes = 95% of total votes.\n- Total votes = 25, 200 × 100\n95 ≈26, 526.\nStep 5: Calculate difference.\n10'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 18}, page_content='- Difference = 10% of 26,526 ≈2, 653.\nAnswer: The difference in valid votes is approximately 2,653.\n11')]

# %%
len(pages)
# Out:
# 19

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=20)
docs=text_splitter.split_documents(pages)
docs
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 0}, page_content='1\nIntroduction\n2\nPercentage Splitting Technique\nThe percentage splitting method involves breaking down a percentage into smaller, man-\nageable parts, calculating each part, and summing the results.\n2.1\nSteps\n1. Identify the whole value and the percentage to calculate.\n2. Break the percentage into simpler parts (e.g., 50%, 25%, 10%, 5%, 1%).\n3. Calculate each part based on the whole value.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 0}, page_content='4. Sum the parts to ﬁnd the ﬁnal result.\n2.2\nCommon Splits\n• 100% = Whole value.\n• 50% = Whole ÷ 2.\n• 25% = 50% ÷ 2.\n• 10% = Whole ÷ 10.\n• 5% = 10% ÷ 2.\n• 1% = Whole ÷ 100.\n3\nTips for Percentage Splitting\n• Start with larger percentages (e.g., 50%, 25%) to minimize steps.\n• Use 10% and 1% for ﬁne adjustments.\n• Practice mental division to compute 50%, 10%, etc., quickly.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 0}, page_content='• Double-check by approximating: e.g., 77.5% is close to 75%, so the answer should\nbe slightly more than 75%.\n4\nExamples\n4.1\nExample 1: 77.5% of 200 (Basic Splitting)\nBreak down 77.5%:\n• 100% = 200.\n• 50% = 200 ÷ 2 = 100.\n• 25% = 100 ÷ 2 = 50.\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 1}, page_content='• 2.5% = 25% ÷ 10 = 50 ÷ 10 = 5.\nCompose 77.5% = 50% + 25% + 2.5%:\n100 + 50 + 5 = 155\nSo, 77.5% of 200 = 155.\n4.2\nExample 2: 65% of 128 (Adjusting with Smaller Percent-\nages)\nBreak down 65%:\n• 100% = 128.\n• 50% = 128 ÷ 2 = 64.\n• 10% = 128 ÷ 10 = 12.8.\n• 5% = 10% ÷ 2 = 12.8 ÷ 2 = 6.4.\nCompose 65% = 50% + 10% + 5%:\n64 + 12.8 + 6.4 = 83.2\nSo, 65% of 128 = 83.2.\n4.3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 1}, page_content='4.3\nExample 3: 37.5% of 80 (Budget Allocation)\nA student has a monthly budget of $80 and spends 37.5% on books. How much do they\nspend? Break down 37.5%:\n• 100% = 80.\n• 25% = 80 ÷ 4 = 20.\n• 10% = 80 ÷ 10 = 8.\n• 2.5% = 25% ÷ 10 = 20 ÷ 10 = 2.\nCompose 37.5% = 25% + 10% + 2.5%:\n20 + 8 + 2 = 30\nSo, the student spends $30 on books.\n5\nReal-Life TCS NQT Examples'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 1}, page_content='The following examples reﬂect real-life scenarios often tested in the TCS NQT exam’s\nnumerical ability section, solved using percentage splitting.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 2}, page_content='5.1\nExample 4: Proﬁt Calculation\nA shopkeeper buys an item for $200 and sells it at a 17.5% proﬁt. What is the selling\nprice? First, calculate the proﬁt amount (17.5% of 200):\n• 100% = 200.\n• 10% = 200 ÷ 10 = 20.\n• 5% = 10% ÷ 2 = 20 ÷ 2 = 10.\n• 2.5% = 5% ÷ 2 = 10 ÷ 2 = 5.\nCompose 17.5% = 10% + 5% + 2.5%:\n20 + 10 + 5 = 35\nProﬁt = $35. Selling Price = Cost Price + Proﬁt = 200 + 35 = $235.\n5.2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 2}, page_content='5.2\nExample 5: Election Voting\nIn an election, a candidate receives 62.5% of 800 valid votes. How many votes did the\ncandidate get? Break down 62.5%:\n• 100% = 800.\n• 50% = 800 ÷ 2 = 400.\n• 12.5% = 50% ÷ 4 = 400 ÷ 4 = 100.\nCompose 62.5% = 50% + 12.5%:\n400 + 100 = 500\nThe candidate received 500 votes.\n5.3\nExample 6: Discount on a Product\nA laptop priced at $1200 has a 22.5% discount during a sale.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 2}, page_content='What is the discount\namount? Break down 22.5%:\n• 100% = 1200.\n• 20% = 1200 ÷ 5 = 240.\n• 2.5% = 25% ÷ 10 = (1200 ÷ 4) ÷ 10 = 300 ÷ 10 = 30.\nCompose 22.5% = 20% + 2.5%:\n240 + 30 = 270\nThe discount amount is $270.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 3}, page_content='5.4\nExample 7: Employee Salary Increment\nAn employees salary of $50,000 increases by 12.5% after a promotion. What is the new\nsalary? First, calculate the increment (12.5% of 50,000):\n• 100% = 50,000.\n• 10% = 50,000 ÷ 10 = 5,000.\n• 2.5% = 25% ÷ 10 = (50,000 ÷ 4) ÷ 10 = 12,500 ÷ 10 = 1,250.\nCompose 12.5% = 10% + 2.5%:\n5, 000 + 1, 250 = 6, 250'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 3}, page_content='Increment = $6,250. New Salary = 50,000 + 6,250 = $56,250.\n6\nPractice Questions\n1. Find 62.5% of 160 using percentage splitting.\n2. Calculate 87.5% of 40 by breaking it into simpler parts.\n3. What is 42.5% of 200 using the splitting method?\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 4}, page_content='Detailed Solution for Percentage Change Problems\nJune 12, 2025\nIntroduction\nThis document provides a detailed solution to two problems involving percentage changes.\nThe first problem calculates the reduction in consumption of a commodity when its price\nincreases, keeping expenditure constant. The second problem determines the percent-'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 4}, page_content='age by which one quantity is less or more than another after a percentage change. All\ncalculations are verified with the given formulas.\n1\nReduction in Consumption Due to Price Increase\n1.1\nProblem Statement\nIf the price of a commodity increases by R%, we need to find the reduction in consumption\nto keep the expenditure constant. The given data is as follows:\n• Initial price: Rs 10/kg'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 4}, page_content='• Initial consumption: 20 kg\n• Total expenditure: Rs 200/month\n• New price after increase: Rs 20/kg\n• Expenditure remains constant at Rs 200/month\nThe formula provided is:\n• If price increases by R%, reduction in consumption =\n100\n100 + R × 100%\n• If price decreases by R%, reduction in consumption =\n100\n100 −R × 100%\n1.2\nSolution\n1. Calculate Initial Expenditure:\nInitial price = 10 Rs/kg,'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 4}, page_content='Initial consumption = 20 kg\nTotal expenditure = Price × Consumption = 10 × 20 = 200 Rs/month\n2. Determine New Consumption After Price Increase:\nNew price = 20 Rs/kg,\nExpenditure = 200 Rs/month\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 5}, page_content='Let the new consumption be Y kg. Since expenditure remains constant:\nNew price × New consumption = Expenditure\n20 × Y = 200\nY = 200\n20 = 10 kg\nSo, consumption reduces from 20 kg to 10 kg.\n3. Calculate Percentage Increase in Price (R%):\nInitial price = 10 Rs/kg,\nNew price = 20 Rs/kg\nIncrease in price = 20 −10 = 10 Rs/kg\nR = Increase in price\nInitial price\n× 100 = 10\n10 × 100 = 100%'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 5}, page_content='10 × 100 = 100%\n4. Calculate Reduction in Consumption:\nInitial consumption = 20 kg,\nNew consumption = 10 kg\nReduction in consumption = 20 −10 = 10 kg\nPercentage reduction = Reduction in consumption\nInitial consumption\n× 100 = 10\n20 × 100 = 50%\n5. Verify Using the Given Formula: For price increase by R%:\nReduction in consumption =\n100\n100 + R × 100%\nHere, R = 100:\nReduction =\n100'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 5}, page_content='Reduction =\n100\n100 + 100 × 100 = 100\n200 × 100 = 50%\nThis matches our calculation.\n6. Explanation of the Formula: Expenditure = Price × Consumption. If price in-\ncreases by R%, new price = Initial price ×100 + R\n100\n. To keep expenditure constant:\nNew consumption = Initial consumption ×\n100\n100 + R\nPercentage reduction =\n(\n1 −\n100\n100 + R\n)\n× 100 =\nR\n100 + R × 100%\n1.3\nConclusion'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 5}, page_content='1.3\nConclusion\nThe price increased by 100%, and consumption reduced by 50% to keep expenditure\nconstant at Rs 200/month. The formula\n100\n100 + R × 100% is verified.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 6}, page_content='2\nPercentage Comparison Between Two Quantities\n2.1\nProblem Statement\nIf A is R% more than B, then B is less than A by some percentage. If A is R% less than\nB, then B is more than A by some percentage. The given data is:\n• A = 120, B = 100\nThe formulas provided are:\n• B is less than A by\nR\n100 + R × 100%\n• B is more than A by\nR\n100 −R × 100%\n2.2\nSolution\n1. Case 1: A is R% More Than B:\nB = 100,'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 6}, page_content='B = 100,\nA = 120\nA = B × 100 + R\n100\n120 = 100 × 100 + R\n100\n100 + R\n100\n= 120\n100\n100 + R = 120\nR = 20\nSo, A is 20% more than B.\n2. Calculate How Much Less B is Than A:\nA = 120,\nB = 100\nDifference = A −B = 120 −100 = 20\nPercentage by which B is less than A = A −B\nA\n×100 = 20\n120×100 = 100\n6\n≈16.67%\n3. Verify Using the Given Formula:\nPercentage =\nR\n100 + R × 100%\nR = 20\n20\n100 + 20 × 100 = 20'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 6}, page_content='100 + 20 × 100 = 20\n120 × 100 = 100\n6\n≈16.67%\nThis matches our calculation.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 7}, page_content='4. Explanation of the Formula:\nA = B × 100 + R\n100\nB = A ×\n100\n100 + R\nPercentage by which B is less than A =\n(\n1 −\n100\n100 + R\n)\n× 100 =\nR\n100 + R × 100%\n5. Case 2: If A is R% Less Than B: The formula for when A is R% less than B,\nand we need to find how much more B is than A, is:\nR\n100 −R × 100%\n2.3\nConclusion\nWhen A = 120 and B = 100, A is 20% more than B, and B is 16.67% less than A. The'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 7}, page_content='formula\nR\n100 + R × 100% is verified.\n3\nGeneral Formulas\n• Price increases by R%: Reduction in consumption =\n100\n100 + R × 100%\n• Price decreases by R%: Reduction in consumption =\n100\n100 −R × 100%\n• A is R% more than B: B is less than A by\nR\n100 + R × 100%\n• A is R% less than B: B is more than A by\nR\n100 −R × 100%\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 8}, page_content='Compound Growth: Population Increase Over Time\nConcept Overview\nThis section deals with calculating the population of a town that grows at a constant rate\nof R% per year over n years, starting from an initial population P. This is an example\nof compound growth, where the increase each year is applied to the new population.\nFormula\nPopulation after n years = P\n(\n1 + R\n100\n)n\nExplanation of Formula'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 8}, page_content='The formula represents compound growth:\n• P is the initial population.\n• R is the annual growth rate in percentage.\n• n is the number of years.\n• Each year, the population increases by R% of the previous year’s population. After\n1 year, the population is P\n(\n1 +\nR\n100\n)\n. After 2 years, it’s P\n(\n1 +\nR\n100\n)2, and after n\nyears, it’s P\n(\n1 +\nR\n100\n)n.\nApplications and Tips'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 8}, page_content='• Applications: Used in demographics, urban planning, and financial growth sce-\nnarios (like compound interest).\n• Tip 1 – Multiplier Method: Convert R% to a multiplier: 1+ R\n100. For R = 10%,\nthe multiplier is 1.1.\n• Tip 2 – Memorize Common Powers: For R = 10%, (1.1)2 = 1.21, (1.1)3 =\n1.331. This helps in quick calculations.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 8}, page_content='• Tip 3 – Verify First Year: After 1 year, the population should be P × (1 + R\n100),\nwhich is a good check.\nExamples with Detailed Steps\nExample 1: Population Growth Calculation\nProblem: A town has a population of 10,000, and it increases at 5% per year. What will\nthe population be after 3 years?\nSolution:\nStep 1: Identify the given values.\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 9}, page_content='- Initial population, P = 10, 000.\n- Growth rate, R = 5%.\n- Number of years, n = 3.\nStep 2: Apply the formula.\n- Formula: Population = P\n(\n1 +\nR\n100\n)n.\n- Substitute the values: Population = 10, 000\n(\n1 +\n5\n100\n)3.\nStep 3: Calculate the multiplier.\n- 1 +\n5\n100 = 1 + 0.05 = 1.05.\nStep 4: Compute the power (1.05)3.\n- First, (1.05)2 = 1.05 × 1.05 = 1.1025.\n- Then, (1.05)3 = 1.1025 × 1.05 = 1.157625.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 9}, page_content='Step 5: Calculate the final population.\n- Population = 10, 000 × 1.157625 = 11, 576.25.\nAnswer: The population after 3 years is approximately 11,576.\nExample 2: Time to Double Population\nProblem: A town’s population is 20,000, growing at 10% per year. In how many years\nwill it double?\nSolution:\nStep 1: Identify the given values.\n- Initial population, P = 20, 000.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 9}, page_content='- Target population = 2 × 20, 000 = 40, 000.\n- Growth rate, R = 10%.\nStep 2: Set up the equation using the formula.\n- Formula: 40, 000 = 20, 000\n(\n1 + 10\n100\n)n.\n- Simplify:\n40,000\n20,000 = (1.1)n =⇒2 = (1.1)n.\nStep 3: Estimate n by calculating powers of 1.1.\n- (1.1)7 ≈1.9487 (since 1.1 × 1.1 = 1.21, 1.21 × 1.1 = 1.331, etc.).\n- (1.1)8 ≈2.1436.\nStep 4: Determine the range.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 9}, page_content='- Since (1.1)7 < 2 and (1.1)8 > 2, n is between 7 and 8 years.\n- For precision, use logarithms: n =\nlog(2)\nlog(1.1) ≈7.27.\nAnswer: The population doubles in approximately 7.27 years.\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 10}, page_content='Compound Depreciation: Value Decrease Over Time\nConcept Overview\nThis section calculates the value of an object that depreciates at a rate of R% per year\nover n years, starting from an initial value P. Depreciation is the opposite of growth,\nwhere the value decreases annually.\nFormula\nValue after n years = P\n(\n1 −R\n100\n)n\nExplanation of Formula\nThe formula represents compound depreciation:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 10}, page_content='• P is the initial value.\n• R is the annual depreciation rate in percentage.\n• n is the number of years.\n• Each year, the value decreases by R% of the previous year’s value. After 1 year,\nthe value is P\n(\n1 −\nR\n100\n)\n. After n years, it’s P\n(\n1 −\nR\n100\n)n.\nApplications and Tips\n• Applications: Used for assets like cars, machinery, or electronics that lose value\nover time.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 10}, page_content='over time.\n• Tip 1 – Multiplier Method: For R = 10%, the depreciation multiplier is 1−10\n100 =\n0.9.\n• Tip 2 – Memorize Powers: For R = 10%, (0.9)2 = 0.81, (0.9)3 = 0.729.\n• Tip 3 – First Year Check: After 1 year, the value should be P × (1 −\nR\n100).\nExamples with Detailed Steps\nExample 1: Car Depreciation\nProblem: A car is worth Rs 500,000 and depreciates at 15% per year. What is its value'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 10}, page_content='after 2 years?\nSolution:\nStep 1: Identify the given values.\n- Initial value, P = 500, 000.\n- Depreciation rate, R = 15%.\n- Number of years, n = 2.\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 11}, page_content='Step 2: Apply the formula.\n- Formula: Value = P\n(\n1 −\nR\n100\n)n.\n- Substitute the values: Value = 500, 000\n(\n1 −15\n100\n)2.\nStep 3: Calculate the multiplier.\n- 1 −15\n100 = 1 −0.15 = 0.85.\nStep 4: Compute the power (0.85)2.\n- (0.85)2 = 0.85 × 0.85 = 0.7225.\nStep 5: Calculate the final value.\n- Value = 500, 000 × 0.7225 = 361, 250.\nAnswer: The car’s value after 2 years is Rs 361,250.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 11}, page_content='Example 2: Machine Value Threshold\nProblem: A machine worth Rs 100,000 depreciates at 20% per year. After how many\nyears will its value be less than Rs 40,000?\nSolution:\nStep 1: Identify the given values.\n- Initial value, P = 100, 000.\n- Target value < 40,000.\n- Depreciation rate, R = 20%.\nStep 2: Set up the equation.\n- Formula: 40, 000 = 100, 000\n(\n1 −20\n100\n)n.\n- Simplify:\n40,000'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 11}, page_content='- Simplify:\n40,000\n100,000 = (0.8)n =⇒0.4 = (0.8)n.\nStep 3: Estimate n by calculating powers of 0.8.\n- (0.8)2 = 0.64.\n- (0.8)3 = 0.512.\n- (0.8)4 = 0.4096.\n- (0.8)5 = 0.32768.\nStep 4: Determine when the value is less than 0.4.\n- At n = 4, (0.8)4 = 0.4096, which is just above 0.4.\n- At n = 5, (0.8)5 = 0.32768, which is below 0.4.\n- Therefore, the value drops below 40,000 after 5 years.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 11}, page_content='Answer: The machine’s value is less than Rs 40,000 after 5 years.\nPercentage Allocation: Salary and Expenditure\nConcept Overview\nThis section involves calculating a person’s salary based on their expenditure percentages\nand remaining savings. The total salary is the sum of expenditure and savings, where\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 12}, page_content='percentages of the salary are allocated to various expenses.\nProblem Statement\nDeepak spends 25% of his salary on house rent, 20% on his children’s education, and 10%\non clothes. After these expenses, he is left with Rs 15,600. What is Deepak’s salary?\nOptions: A. 30,000, B. 32,000, C. 31,200, D. 32,500.\nSolution Approach\n• Salary = Expenditure + Savings.\n• Calculate total expenditure percentage.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 12}, page_content='• Savings percentage = 100% - Expenditure percentage.\n• Use the savings amount to find the salary.\nDetailed Steps\nStep 1: Calculate total expenditure percentage.\n- House rent = 25%.\n- Education = 20%.\n- Clothes = 10%.\n- Total expenditure = 25 + 20 + 10 = 55%.\nStep 2: Calculate savings percentage.\n- Savings percentage = 100 −55 = 45%.\nStep 3: Set up the equation for savings.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 12}, page_content='- 45% of Salary = Rs 15,600.\n- Let Salary = S. Then, 0.45S = 15, 600.\nStep 4: Solve for the salary.\n- S = 15,600\n0.45 .\n- Simplify: S = 15, 600 × 100\n45 = 15, 600 × 20\n9 ≈34, 666.67.\nStep 5: Compare with options.\n- Calculated salary ≈34, 667, which does not match any options (30,000, 32,000, 31,200,\n32,500).\n- This suggests a potential error in the problem’s options.\nThe closest option is not'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 12}, page_content='correct, but for the sake of the problem, let’s note the discrepancy.\nAnswer: The calculated salary is approximately Rs 34,667, but none of the options match.\nThere may be an error in the problem’s options.\nExamples with Detailed Steps\nExample 1: Adjusted Savings Percentage\nProblem: A person spends 30% on rent, 15% on food, and 10% on travel. After expenses,\n5'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 13}, page_content='they save Rs 22,500. What is their salary?\nSolution:\nStep 1: Calculate total expenditure percentage.\n- Rent = 30%.\n- Food = 15%.\n- Travel = 10%.\n- Total expenditure = 30 + 15 + 10 = 55%.\nStep 2: Calculate savings percentage.\n- Savings = 100 −55 = 45%.\nStep 3: Set up the equation.\n- 45% of Salary = 22,500.\n- Salary = 22,500\n0.45 .\nStep 4: Solve for the salary.\n- Salary = 22, 500 × 100'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 13}, page_content='45 = 22, 500 × 20\n9 = 50, 000.\nAnswer: The salary is Rs 50,000.\nExample 2: Different Percentages\nProblem: A person spends 20% on rent, 10% on food, and 5% on entertainment. They\nsave Rs 52,500. What is their salary?\nSolution:\nStep 1: Calculate total expenditure percentage.\n- Rent = 20%.\n- Food = 10%.\n- Entertainment = 5%.\n- Total expenditure = 20 + 10 + 5 = 35%.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 13}, page_content='Step 2: Calculate savings percentage.\n- Savings = 100 −35 = 65%.\nStep 3: Set up the equation.\n- 65% of Salary = 52,500.\n- Salary = 52,500\n0.65 .\nStep 4: Solve for the salary.\n- Salary = 52, 500 × 100\n65 = 52, 500 × 20\n13 ≈80, 769.23.\nAnswer: The salary is approximately Rs 80,769.\n6'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='Percentage Change in Area Due to Dimension In-\ncrease\nConcept Overview\nThis section calculates the percentage change in the area of a rectangle when its dimen-\nsions (length and breadth) are increased by given percentages. Since the cost of land is\nproportional to its area, the percentage change in area equals the percentage change in\ncost.\nProblem Statement'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='Problem Statement\nA person increases the length of a rectangular land by 15% and the breadth by 20%.\nFind the percentage change in the cost of the land, assuming land prices are uniform.\nOptions: A. 42%, B. 38%, C. 30%, D. 45%.\nSolution Approach\n• Area of a rectangle = Length × Breadth.\n• New length = Original length ×(1 + Length increase %\n100\n).'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='100\n).\n• New breadth = Original breadth ×(1 + Breadth increase %\n100\n).\n• Percentage change = New Area−Original Area\nOriginal Area\n× 100.\nDetailed Steps\nStep 1: Assume initial dimensions.\n- Let original length = 100 units.\n- Let original breadth = 100 units.\n- Original area = 100 × 100 = 10, 000 square units.\nStep 2: Calculate new dimensions.\n- New length = 100 × (1 + 15'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='100) = 100 × 1.15 = 115 units.\n- New breadth = 100 × (1 + 20\n100) = 100 × 1.20 = 120 units.\nStep 3: Calculate new area.\n- New area = 115 × 120 = 13, 800 square units.\nStep 4: Find the increase in area.\n- Increase = 13, 800 −10, 000 = 3, 800 square units.\nStep 5: Calculate percentage increase.\n- Percentage increase =\n3,800\n10,000 × 100 = 38%.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 14}, page_content='10,000 × 100 = 38%.\nAnswer: The percentage change in cost is 38% (Option B).\n7'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 15}, page_content='Examples with Detailed Steps\nExample 1: Different Increases\nProblem: A rectangle’s length increases by 10% and breadth by 5%. Find the percentage\nincrease in area.\nSolution:\nStep 1: Assume initial dimensions.\n- Length = 100 units.\n- Breadth = 100 units.\n- Original area = 100 × 100 = 10, 000.\nStep 2: Calculate new dimensions.\n- New length = 100 × 1.10 = 110 units.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 15}, page_content='- New breadth = 100 × 1.05 = 105 units.\nStep 3: Calculate new area.\n- New area = 110 × 105 = 11, 550.\nStep 4: Find the increase.\n- Increase = 11, 550 −10, 000 = 1, 550.\nStep 5: Calculate percentage increase.\n- Percentage increase =\n1,550\n10,000 × 100 = 15.5%.\nAnswer: The area increases by 15.5%.\nExample 2: Decrease in Dimensions'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 15}, page_content='Problem: A rectangle’s length decreases by 10% and breadth by 20%. Find the percentage\ndecrease in area.\nSolution:\nStep 1: Assume initial dimensions.\n- Length = 100 units.\n- Breadth = 100 units.\n- Original area = 100 × 100 = 10, 000.\nStep 2: Calculate new dimensions.\n- New length = 100 × (1 −0.10) = 90 units.\n- New breadth = 100 × (1 −0.20) = 80 units.\nStep 3: Calculate new area.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 15}, page_content='- New area = 90 × 80 = 7, 200.\nStep 4: Find the decrease.\n- Decrease = 10, 000 −7, 200 = 2, 800.\nStep 5: Calculate percentage decrease.\n- Percentage decrease =\n2,800\n10,000 × 100 = 28%.\n8'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='Answer: The area decreases by 28%.\nElection Voting with Percentage Difference\nConcept Overview\nThis section deals with calculating the difference in votes between two parties in an\nelection, where one party secures a percentage more votes than the other, and the total\nvotes are split between them.\nProblem Statement'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='Problem Statement\nIn an election contested by two parties, Party A secured 12% more of the total votes than\nParty B. Party B got 13,200 votes, and there are no invalid votes. By how many votes\ndid Party B lose the election?\nOptions: A. 1,600, B. 2,500, C. 2,400, D. 3,600.\nSolution Approach\n• Party A’s votes are 12% more than Party B’s.\n• Total votes = Party A votes + Party B votes.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='• Find total votes, then calculate the difference.\nDetailed Steps\nStep 1: Define votes in terms of percentages.\n- Let Party B’s votes = 100 units (for percentage calculation).\n- Party A’s votes = 100 × (1 + 0.12) = 112 units.\n- Total votes = 100 + 112 = 212 units.\nStep 2: Calculate percentage split.\n- Party B’s percentage = 100\n212 × 100 ≈47.17%.\n- Party A’s percentage = 112\n212 × 100 ≈52.83%.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='212 × 100 ≈52.83%.\n- Difference = 52.83 −47.17 = 12% of total votes (as given).\nStep 3: Use Party B’s votes to find total votes.\n- Party B = 13,200 votes, which is 47.17% of total.\n- Total votes = 13,200\n0.4717 ≈27, 984.\n- Alternatively, use the diagram’s approach: If Party B = 44% (since A is 12% more, A\n= 56%, total = 100% - 12% = 88%, B = 44%), then:\n- Total votes = 13,200\n0.44 = 30, 000.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 16}, page_content='0.44 = 30, 000.\nStep 4: Calculate Party A’s votes.\n- Party A = 56% of 30,000 = 0.56 × 30, 000 = 16, 800.\nStep 5: Find the difference.\n- Difference = 16, 800 −13, 200 = 3, 600.\n9'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 17}, page_content='Answer: Party B lost by 3,600 votes (Option D).\nExamples with Detailed Steps\nExample 1: Different Percentage Difference\nProblem: Party A gets 20% more votes than Party B. Party B has 10,000 votes. Find\nthe difference.\nSolution:\nStep 1: Define votes.\n- Party B = 100 units.\n- Party A = 100 × 1.20 = 120 units.\n- Total = 100 + 120 = 220 units.\nStep 2: Calculate percentage split.\n- Party B = 100'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 17}, page_content='- Party B = 100\n220 × 100 ≈45.45%.\nStep 3: Find total votes.\n- 45.45% = 10,000.\n- Total votes = 10,000\n0.4545 ≈22, 000.\nStep 4: Calculate difference.\n- Difference = 20% of 22,000 = 0.20 × 22, 000 = 4, 400.\nAnswer: The difference is 4,400 votes.\nExample 2: With Invalid Votes\nProblem: Party A gets 10% more votes than Party B. Party B has 12,000 votes, and 5%'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 17}, page_content='of total votes are invalid. Find the difference in valid votes.\nSolution:\nStep 1: Define votes.\n- Party B = 100 units.\n- Party A = 100 × 1.10 = 110 units.\n- Total valid votes = 100 + 110 = 210 units.\nStep 2: Calculate percentage of valid votes.\n- Party B = 100\n210 × 100 ≈47.62%.\nStep 3: Find total valid votes.\n- 47.62% = 12,000.\n- Total valid votes = 12,000\n0.4762 ≈25, 200.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 17}, page_content='0.4762 ≈25, 200.\nStep 4: Include invalid votes.\n- Valid votes = 95% of total votes.\n- Total votes = 25, 200 × 100\n95 ≈26, 526.\nStep 5: Calculate difference.\n10'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'file_path': 'C:\\Users\\Admin\\Documents\\Aptitude\\percetnages_merged.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-06-12T14:43:26+00:00', 'trapped': '', 'modDate': 'D:20250612144326Z', 'creationDate': '', 'page': 18}, page_content='- Difference = 10% of 26,526 ≈2, 653.\nAnswer: The difference in valid votes is approximately 2,653.\n11')]

# %%
from config import Config
import psycopg2

# Step 3: Store in NeonDB using pgvector
vector_db = PGVector.from_documents(
    documents=docs,
    embedding=embeddings,
    collection_name="my_pgvector_collection",
    connection_string=Config.PGVECTOR_URL,
)

# %%
# Import required libraries
import os
from dotenv import load_dotenv
from langchain.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Weaviate
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA
import weaviate

# Load environment variables
load_dotenv()

# Initialize Weaviate client
weaviate_url = os.environ.get("WEAVIATE_URL", "http://localhost:8080")
weaviate_api_key = os.environ.get("WEAVIATE_API_KEY")

if weaviate_api_key:
    client = weaviate.Client(
        url=weaviate_url,
        auth_client_secret=weaviate.AuthApiKey(weaviate_api_key)
    )
else:
    client = weaviate.Client(url=weaviate_url)

# Verify connection
print("Weaviate Connected:", client.is_ready())

# Initialize embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Load and process PDF
pdf_path = r"C:\Users\Admin\Documents\Aptitude\percetnages_merged.pdf"
loader = PyMuPDFLoader(pdf_path, extract_images=True)
documents = loader.load()

# Split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len
)
chunks = text_splitter.split_documents(documents)

# Create Weaviate schema
schema = {
    "class": "Document",
    "properties": [
        {
            "name": "content",
            "dataType": ["text"]
        },
        {
            "name": "metadata",
            "dataType": ["object"]
        }
    ],
    "vectorizer": "none"
}

# Delete existing class if it exists
if client.schema.exists("Document"):
    client.schema.delete_class("Document")

# Create schema
client.schema.create_class(schema)

# Initialize Weaviate vector store
vectorstore = Weaviate(
    client=client,
    index_name="Document",
    text_key="content",
    embedding=embeddings,
    attributes=["metadata"]
)

# Add documents to vector store
vectorstore.add_documents(chunks)

# Initialize ChatGroq
llm = ChatGroq(
    model="mixtral-8x7b-32768",
)

# Create RetrievalQA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={"k": 3}),
    return_source_documents=True
)

# Example query
query = "How do you calculate 62.5% of 160 using percentage splitting?"
result = qa_chain({"query": query})

# Print results
print("\nQuery:", query)
print("Answer:", result["result"])
print("\nSource Documents:")
for doc in result["source_documents"]:
    print(f"- Page {doc.metadata['page']}: {doc.page_content[:200]}...")
